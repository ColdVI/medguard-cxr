# %% [markdown]
# # Phase 3 Grounded Localization Samples
#
# These overlays are synthetic smoke artifacts for pipeline and visual-audit plumbing only. They are not clinical evidence and do not estimate MedGuard-CXR localization performance. Real VinDr-CXR overlays must replace this section once the dataset is available locally.

# %%
from IPython.display import Image, display

from scripts.generate_synthetic_overlays import main as generate_synthetic_overlays

generate_synthetic_overlays([
    "--output-dir", "results/overlays",
    "--count", "20",
    "--seed", "2026",
])
display(Image(filename="results/overlays/grid.png"))
